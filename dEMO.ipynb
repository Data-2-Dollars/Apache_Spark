# %%
# %sql
-- Create a clean playground schema
CREATE SCHEMA IF NOT EXISTS workspace.table_demo;
USE workspace.table_demo;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Create a Managed Table
CREATE TABLE IF NOT EXISTS managed_employees (
    emp_id INT,
    emp_name STRING,
    department STRING
) USING DELTA;

-- Insert some dummy records
INSERT INTO managed_employees VALUES 
(1, 'Alice', 'Data Science'),
(2, 'Bob', 'Data Engineering');

-- Check table details (Look closely at the "Location" field in the output)
DESCRIBE DETAIL managed_employees;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- 1. Drop the managed table you just created
--DROP TABLE managed_employees;
UNDROP TABLE managed_employees;
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-5544485802933736>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', '-- 1. Drop the managed table you just created\n--DROP TABLE managed_employees;\nUNDROP TABLE managed_employees;\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %sql
SELECT * FROM managed_employees;

# %%
# %sql
-- 2. Try to read the raw files from that S3 path
-- (Replace with the actual S3 path you copied from DESCRIBE DETAIL)
SELECT * FROM delta.`s3://databricks-aterhwtdb8q47wjvdsx1fy-cloud-storage-bucket/unity-catalog/7474644158161715/__unitystorage/schemas/a5577716-0cf1-4114-9d77-45dccd7c39e2/tables/7fd083b0-8fc0-4217-ace4-fb56231580f7/`;

# %%
# %sql
CREATE TABLE IF NOT EXISTS external_employees (
    emp_id INT,
    emp_name STRING,
    department STRING
) 
USING DELTA
COMMENT 'Create a foreign table referencing external data source via a foreign catalog'

# %%
# %sql
CREATE EXTERNAL VOLUME BRONZE_LAYER.DEMO.EXT_VOL
LOCATION 's3://databricks-aterhwtdb8q47wjvdsx1fy-cloud-storage-bucket/unity-catalog/vol_demo';
